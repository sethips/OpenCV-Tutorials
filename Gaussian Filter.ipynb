# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
help(cv2.GaussianBlur)
# Out:
# Help on built-in function GaussianBlur:
#
# GaussianBlur(...)
#     GaussianBlur(src, ksize, sigmaX[, dst[, sigmaY[, borderType]]]) -> dst

# %%
cd ../
# Out:
# /home/krshrimali/Documents/Python/tkinter

# %%
img = cv2.imread('Me1.png')
filter = cv2.GaussianBlur(img, (5,5), 0)

# %%
plt.subplot(121), plt.imshow(img), plt.title('Original')
plt.subplot(122), plt.imshow(filter), plt.title('Blurred')
plt.show()

# %%
import cv2

cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi', fourcc, 20.0, (640, 480))

while True:
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    out.write(frame)
    cv2.imshow('frame', frame)
    cv2.imshow('frame2', gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()

# %%
pwd
# Out:
# u'/home/krshrimali/Documents/Python/tkinter/opencv'
